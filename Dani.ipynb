# %%
import pandas as pd

# %%
raw = pd.read_excel('Resultados 2da visita.xlsx')

# %%
raw.head()
# Out:
#    Trial  Participante 1  Participante 2  Participante 3  Participante 4  \
# 0      1            21.0            13.0            30.0            40.0
# 1      2            24.0             0.0            89.0            60.0
# 2      3             1.0             0.0            12.0            59.0
# 3      4             0.0             3.0             1.0            79.0
# 4      5             0.0             0.0             4.0            88.0
#
#    Participante 5  Participante 6  Participante 7  Participante 8  \
# 0              28            11.0              20            92.0
# 1               0             2.0              43            12.0
# 2              13             0.0               5            19.0
# 3               2             0.0               6            16.0
# 4              56             0.0               4             3.0
#
#    Participante 9        ...          Participante 3.1  Participante 4.1  \
# ...

# %%
for column in raw.columns:
    if raw[column].isnull().all():
        rawdr = raw.drop(column, axis = 1)

# %%
normdf = rawdr.ix[:,13:]

# %%
normdf
# Out:
#    Trial.1  Participante 1.1  Participante 2.1  Participante 3.1  \
# 0        1          0.116667          0.072222          0.166667
# 1        2          0.133333          0.000000          0.494444
# 2        3          0.005556          0.000000          0.066667
# 3        4          0.000000          0.016667          0.005556
# 4        5          0.000000          0.000000          0.022222
# 5        6          0.005556          0.038889          0.027778
# 6        7          0.000000          0.000000          0.005556
# 7        8               NaN          0.005556          0.005556
# 8        9               NaN               NaN          0.000000
# 9       10               NaN               NaN               NaN
#
#    Participante 4.1  Participante 5.1  Participante 6.1  Participante 7.1  \
# 0          0.222222          0.155556          0.061111          0.111111
# 1          0.333333          0.000000          0.011111          0.238889
# ...
